# %%
## All Imports
import glob
import random
from bs4 import BeautifulSoup

# %%
## Parameters
N_SAMPLES = 5
N_ESTIMATORS = 10
TRAIN_SIZE = 0.75
HTML_PATH = "*/*.html"

# %%
## All Functions
def text_from_html(html):
    soup = BeautifulSoup(html)

    # kill all script and style elements
    for script in soup(["script", "style"]):
        script.extract()    # rip it out

    # get text
    text = soup.get_text()

    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    text = '\n'.join(chunk for chunk in chunks if chunk)

    return text

def split_phrases_setfy(text):
    return set(text.lower().replace('\n', '.').replace('¶', '.').replace('. ', '.').split('.'))


def get_similarity(html1, html2, corpus_intersect):
    
    clean_sets = html1-corpus_intersect
    clean_sets1 = html2-corpus_intersect
    similarity = len(clean_sets.intersection(clean_sets1))/len(clean_sets.union(clean_sets1))
    return similarity

def read_html(h):
    with open(h) as f:
        html = f.read()
    return html

def html_text_from_path(html_path):
    h = read_html(html_path)
    h = text_from_html(h)
    h = split_phrases_setfy(h)
    return h

def get_corpus_intersect(all_html, n_samples):
    html_path_sample = random.sample(all_html, n_samples)
    html_sources = [read_html(h) for h in html_path_sample]
    html_sources = [text_from_html(h) for h in html_sources]
    html_sets = [split_phrases_setfy(h) for h in html_sources]
    corpus_intersect = set.intersection(*html_sets)
    return corpus_intersect

def intersect_model(all_html, n_samples, n_estimators):
    all_models = []
    for n in range(n_estimators):
        all_models.append(get_corpus_intersect(all_html, n_samples))

    model = set.union(*all_models)
    return model

# %%
# Get filepaths of htmls
all_html = glob.glob(HTML_PATH)
#all_html = [h for h in all_html if 'PT' not in h]

# %%
# Train test split
train_samples = int(TRAIN_SIZE*len(all_html))
train_html = all_html[:train_samples]
test_html = all_html[train_samples:]

# %%
# Create set of common sentences among those documents
model = intersect_model(train_html, N_SAMPLES, N_ESTIMATORS)

# %%
# Compare documents in the test set
for i, h1 in enumerate(test_html[:-1]):
    for j in range(i+1, len(test_html)):
        print('='*80)
        print(f'Index {i} vs idx {j}')
        h2 = test_html[j]
        h_text_1 = html_text_from_path(h1)
        h_text_2 = html_text_from_path(h2)
        similarity = get_similarity(h_text_1, h_text_2, model)
        print(f'Similarity is {similarity}')
# Out:
# ================================================================================
# Index 0 vs idx 1
# Similarity is 0.6734006734006734
# ================================================================================
# Index 0 vs idx 2
# Similarity is 0.10594315245478036
# ================================================================================
# Index 0 vs idx 3
# Similarity is 0.06443914081145585
# ================================================================================
# Index 0 vs idx 4
# Similarity is 0.08533333333333333
# ================================================================================
# Index 0 vs idx 5
# Similarity is 0.06179775280898876
# ================================================================================
# Index 0 vs idx 6
# Similarity is 0.09976798143851508
# ================================================================================
# Index 0 vs idx 7
# Similarity is 0.0979020979020979
# ================================================================================
# Index 0 vs idx 8
# Similarity is 0.10250569476082004
# ================================================================================
# Index 0 vs idx 9
# Similarity is 0.08423913043478261
# ================================================================================
# Index 0 vs idx 10
# Similarity is 0.05152671755725191
# ================================================================================
# Index 0 vs idx 11
# Similarity is 0.055865921787709494
# ================================================================================
# Index 0 vs idx 12
# Similarity is 0.08235294117647059
# ================================================================================
# Index 0 vs idx 13
# Similarity is 0.07526881720430108
# ================================================================================
# Index 0 vs idx 14
# Similarity is 0.059278350515463915
# ================================================================================
# Index 0 vs idx 15
# Similarity is 0.05747126436781609
# ================================================================================
# Index 0 vs idx 16
# Similarity is 0.0945273631840796
# ================================================================================
# Index 0 vs idx 17
# Similarity is 0.058931860036832415
# ================================================================================
# Index 0 vs idx 18
# Similarity is 0.09965034965034965
# ================================================================================
# Index 0 vs idx 19
# Similarity is 0.058673469387755105
# ================================================================================
# Index 0 vs idx 20
# Similarity is 0.09234828496042216
# ================================================================================
# Index 0 vs idx 21
# Similarity is 0.07692307692307693
# ================================================================================
# Index 0 vs idx 22
# Similarity is 0.09287925696594428
# ================================================================================
# Index 0 vs idx 23
# Similarity is 0.06971153846153846
# ================================================================================
# Index 0 vs idx 24
# Similarity is 0.055944055944055944
# ================================================================================
# Index 0 vs idx 25
# Similarity is 0.040584415584415584
# ================================================================================
# Index 0 vs idx 26
# Similarity is 0.06565656565656566
# ================================================================================
# Index 0 vs idx 27
# Similarity is 0.04081632653061224
# ================================================================================
# Index 0 vs idx 28
# Similarity is 0.06565656565656566
# ================================================================================
# Index 0 vs idx 29
# Similarity is 0.12
# ================================================================================
# Index 0 vs idx 30
# Similarity is 0.037037037037037035
# ================================================================================
# Index 0 vs idx 31
# Similarity is 0.10025062656641603
# ================================================================================
# Index 0 vs idx 32
# Similarity is 0.05141388174807198
# ================================================================================
# Index 0 vs idx 33
# Similarity is 0.07323232323232323
# ================================================================================
# Index 0 vs idx 34
# Similarity is 0.05102040816326531
# ================================================================================
# Index 0 vs idx 35
# Similarity is 0.11180124223602485
# ================================================================================
# Index 0 vs idx 36
# Similarity is 0.07520325203252033
# ================================================================================
# Index 0 vs idx 37
# Similarity is 0.06629834254143646
# ================================================================================
# Index 0 vs idx 38
# Similarity is 0.06199460916442048
# ================================================================================
# Index 0 vs idx 39
# Similarity is 0.08312958435207823
# ================================================================================
# Index 0 vs idx 40
# Similarity is 0.08232445520581114
# ================================================================================
# Index 0 vs idx 41
# Similarity is 0.06299212598425197
# ================================================================================
# Index 0 vs idx 42
# Similarity is 0.06038647342995169
# ================================================================================
# Index 1 vs idx 2
# Similarity is 0.0855106888361045
# ================================================================================
# Index 1 vs idx 3
# Similarity is 0.07954545454545454
# ================================================================================
# Index 1 vs idx 4
# Similarity is 0.08188585607940446
# ================================================================================
# Index 1 vs idx 5
# Similarity is 0.04929577464788732
# ================================================================================
# Index 1 vs idx 6
# Similarity is 0.07478632478632478
# ================================================================================
# Index 1 vs idx 7
# Similarity is 0.07526881720430108
# ================================================================================
# Index 1 vs idx 8
# Similarity is 0.07547169811320754
# ================================================================================
# Index 1 vs idx 9
# Similarity is 0.10309278350515463
# ================================================================================
# Index 1 vs idx 10
# Similarity is 0.06227106227106227
# ================================================================================
# Index 1 vs idx 11
# Similarity is 0.06618962432915922
# ================================================================================
# Index 1 vs idx 12
# Similarity is 0.07297297297297298
# ================================================================================
# Index 1 vs idx 13
# Similarity is 0.06716417910447761
# ================================================================================
# Index 1 vs idx 14
# Similarity is 0.07579462102689487
# ================================================================================
# Index 1 vs idx 15
# Similarity is 0.04121863799283154
# ================================================================================
# Index 1 vs idx 16
# Similarity is 0.09069767441860466
# ================================================================================
# Index 1 vs idx 17
# Similarity is 0.041379310344827586
# ================================================================================
# Index 1 vs idx 18
# Similarity is 0.09849749582637729
# ================================================================================
# Index 1 vs idx 19
# Similarity is 0.05714285714285714
# ================================================================================
# Index 1 vs idx 20
# Similarity is 0.09653465346534654
# ================================================================================
# Index 1 vs idx 21
# Similarity is 0.0880503144654088
# ================================================================================
# Index 1 vs idx 22
# Similarity is 0.0670391061452514
# ================================================================================
# Index 1 vs idx 23
# Similarity is 0.0871559633027523
# ================================================================================
# Index 1 vs idx 24
# Similarity is 0.06925675675675676
# ================================================================================
# Index 1 vs idx 25
# Similarity is 0.0452418096723869
# ================================================================================
# Index 1 vs idx 26
# Similarity is 0.04640371229698376
# ================================================================================
# Index 1 vs idx 27
# Similarity is 0.05169340463458111
# ================================================================================
# Index 1 vs idx 28
# Similarity is 0.04640371229698376
# ================================================================================
# Index 1 vs idx 29
# Similarity is 0.11740041928721175
# ================================================================================
# Index 1 vs idx 30
# Similarity is 0.04753820033955857
# ================================================================================
# Index 1 vs idx 31
# Similarity is 0.07834101382488479
# ================================================================================
# Index 1 vs idx 32
# Similarity is 0.07881773399014778
# ================================================================================
# Index 1 vs idx 33
# Similarity is 0.08353221957040573
# ================================================================================
# Index 1 vs idx 34
# Similarity is 0.07823960880195599
# ================================================================================
# Index 1 vs idx 35
# Similarity is 0.10763209393346379
# ================================================================================
# Index 1 vs idx 36
# Similarity is 0.09197651663405088
# ================================================================================
# Index 1 vs idx 37
# Similarity is 0.07235142118863049
# ================================================================================
# Index 1 vs idx 38
# Similarity is 0.05486284289276808
# ================================================================================
# Index 1 vs idx 39
# Similarity is 0.06306306306306306
# ================================================================================
# Index 1 vs idx 40
# Similarity is 0.060133630289532294
# ================================================================================
# Index 1 vs idx 41
# Similarity is 0.05853658536585366
# ================================================================================
# Index 1 vs idx 42
# Similarity is 0.058823529411764705
# ================================================================================
# Index 2 vs idx 3
# Similarity is 0.041025641025641026
# ================================================================================
# Index 2 vs idx 4
# Similarity is 0.06376811594202898
# ================================================================================
# Index 2 vs idx 5
# Similarity is 0.054
# ================================================================================
# Index 2 vs idx 6
# Similarity is 0.07692307692307693
# ================================================================================
# Index 2 vs idx 7
# Similarity is 0.0775
# ================================================================================
# Index 2 vs idx 8
# Similarity is 0.08292682926829269
# ================================================================================
# Index 2 vs idx 9
# Similarity is 0.06845238095238096
# ================================================================================
# Index 2 vs idx 10
# Similarity is 0.03024193548387097
# ================================================================================
# Index 2 vs idx 11
# Similarity is 0.03536345776031434
# ================================================================================
# Index 2 vs idx 12
# Similarity is 0.07894736842105263
# ================================================================================
# Index 2 vs idx 13
# Similarity is 0.07142857142857142
# ================================================================================
# Index 2 vs idx 14
# Similarity is 0.0480225988700565
# ================================================================================
# Index 2 vs idx 15
# Similarity is 0.06224066390041494
# ================================================================================
# Index 2 vs idx 16
# Similarity is 0.07238605898123325
# ================================================================================
# Index 2 vs idx 17
# Similarity is 0.0636182902584493
# ================================================================================
# Index 2 vs idx 18
# Similarity is 0.02613240418118467
# ================================================================================
# Index 2 vs idx 19
# Similarity is 0.059322033898305086
# ================================================================================
# Index 2 vs idx 20
# Similarity is 0.06857142857142857
# ================================================================================
# Index 2 vs idx 21
# Similarity is 0.06132075471698113
# ================================================================================
# Index 2 vs idx 22
# Similarity is 0.1299638989169675
# ================================================================================
# Index 2 vs idx 23
# Similarity is 0.060209424083769635
# ================================================================================
# Index 2 vs idx 24
# Similarity is 0.04638218923933209
# ================================================================================
# Index 2 vs idx 25
# Similarity is 0.03264604810996564
# ================================================================================
# Index 2 vs idx 26
# Similarity is 0.0821529745042493
# ================================================================================
# Index 2 vs idx 27
# Similarity is 0.042
# ================================================================================
# Index 2 vs idx 28
# Similarity is 0.0821529745042493
# ================================================================================
# Index 2 vs idx 29
# Similarity is 0.07159353348729793
# ================================================================================
# Index 2 vs idx 30
# Similarity is 0.03984819734345351
# ================================================================================
# Index 2 vs idx 31
# Similarity is 0.09615384615384616
# ================================================================================
# Index 2 vs idx 32
# Similarity is 0.054285714285714284
# ================================================================================
# Index 2 vs idx 33
# Similarity is 0.06944444444444445
# ================================================================================
# Index 2 vs idx 34
# Similarity is 0.053824362606232294
# ================================================================================
# Index 2 vs idx 35
# Similarity is 0.06652360515021459
# ================================================================================
# Index 2 vs idx 36
# Similarity is 0.04487179487179487
# ================================================================================
# Index 2 vs idx 37
# Similarity is 0.06134969325153374
# ================================================================================
# Index 2 vs idx 38
# Similarity is 0.06306306306306306
# ================================================================================
# Index 2 vs idx 39
# Similarity is 0.0891891891891892
# ================================================================================
# Index 2 vs idx 40
# Similarity is 0.08533333333333333
# ================================================================================
# Index 2 vs idx 41
# Similarity is 0.031073446327683617
# ================================================================================
# Index 2 vs idx 42
# Similarity is 0.031007751937984496
# ================================================================================
# Index 3 vs idx 4
# Similarity is 0.07541899441340782
# ================================================================================
# Index 3 vs idx 5
# Similarity is 0.052123552123552123
# ================================================================================
# Index 3 vs idx 6
# Similarity is 0.06352941176470588
# ================================================================================
# Index 3 vs idx 7
# Similarity is 0.0665083135391924
# ================================================================================
# Index 3 vs idx 8
# Similarity is 0.057208237986270026
# ================================================================================
# Index 3 vs idx 9
# Similarity is 0.09912536443148688
# ================================================================================
# Index 3 vs idx 10
# Similarity is 0.05588822355289421
# ================================================================================
# Index 3 vs idx 11
# Similarity is 0.06031128404669261
# ================================================================================
# Index 3 vs idx 12
# Similarity is 0.0581039755351682
# ================================================================================
# Index 3 vs idx 13
# Similarity is 0.052924791086350974
# ================================================================================
# Index 3 vs idx 14
# Similarity is 0.08055555555555556
# ================================================================================
# Index 3 vs idx 15
# Similarity is 0.051587301587301584
# ================================================================================
# Index 3 vs idx 16
# Similarity is 0.0663265306122449
# ================================================================================
# Index 3 vs idx 17
# Similarity is 0.05534351145038168
# ================================================================================
# Index 3 vs idx 18
# Similarity is 0.03583617747440273
# ================================================================================
# Index 3 vs idx 19
# Similarity is 0.07084468664850137
# ================================================================================
# Index 3 vs idx 20
# Similarity is 0.07397260273972603
# ================================================================================
# Index 3 vs idx 21
# Similarity is 0.051685393258426963
# ================================================================================
# Index 3 vs idx 22
# Similarity is 0.060897435897435896
# ================================================================================
# Index 3 vs idx 23
# Similarity is 0.07360406091370558
# ================================================================================
# Index 3 vs idx 24
# Similarity is 0.056261343012704176
# ================================================================================
# Index 3 vs idx 25
# Similarity is 0.05272108843537415
# ================================================================================
# Index 3 vs idx 26
# Similarity is 0.03896103896103896
# ================================================================================
# Index 3 vs idx 27
# Similarity is 0.0547945205479452
# ================================================================================
# Index 3 vs idx 28
# Similarity is 0.03896103896103896
# ================================================================================
# Index 3 vs idx 29
# Similarity is 0.06873614190687362
# ================================================================================
# Index 3 vs idx 30
# Similarity is 0.055970149253731345
# ================================================================================
# Index 3 vs idx 31
# Similarity is 0.06377551020408163
# ================================================================================
# Index 3 vs idx 32
# Similarity is 0.08403361344537816
# ================================================================================
# Index 3 vs idx 33
# Similarity is 0.07754010695187166
# ================================================================================
# Index 3 vs idx 34
# Similarity is 0.08333333333333333
# ================================================================================
# Index 3 vs idx 35
# Similarity is 0.06625258799171843
# ================================================================================
# Index 3 vs idx 36
# Similarity is 0.06736842105263158
# ================================================================================
# Index 3 vs idx 37
# Similarity is 0.0963855421686747
# ================================================================================
# Index 3 vs idx 38
# Similarity is 0.06896551724137931
# ================================================================================
# Index 3 vs idx 39
# Similarity is 0.07948717948717948
# ================================================================================
# Index 3 vs idx 40
# Similarity is 0.08418367346938775
# ================================================================================
# Index 3 vs idx 41
# Similarity is 0.07282913165266107
# ================================================================================
# Index 3 vs idx 42
# Similarity is 0.0583756345177665
# ================================================================================
# Index 4 vs idx 5
# Similarity is 0.06526315789473684
# ================================================================================
# Index 4 vs idx 6
# Similarity is 0.07272727272727272
# ================================================================================
# Index 4 vs idx 7
# Similarity is 0.07329842931937172
# ================================================================================
# Index 4 vs idx 8
# Similarity is 0.07908163265306123
# ================================================================================
# Index 4 vs idx 9
# Similarity is 0.08681672025723473
# ================================================================================
# Index 4 vs idx 10
# Similarity is 0.04477611940298507
# ================================================================================
# Index 4 vs idx 11
# Similarity is 0.04979253112033195
# ================================================================================
# Index 4 vs idx 12
# Similarity is 0.06968641114982578
# ================================================================================
# Index 4 vs idx 13
# Similarity is 0.06269592476489028
# ================================================================================
# Index 4 vs idx 14
# Similarity is 0.08359133126934984
# ================================================================================
# Index 4 vs idx 15
# Similarity is 0.06047516198704104
# ================================================================================
# Index 4 vs idx 16
# Similarity is 0.07977207977207977
# ================================================================================
# Index 4 vs idx 17
# Similarity is 0.06198347107438017
# ================================================================================
# Index 4 vs idx 18
# Similarity is 0.02527075812274368
# ================================================================================
# Index 4 vs idx 19
# Similarity is 0.06948640483383686
# ================================================================================
# Index 4 vs idx 20
# Similarity is 0.08615384615384615
# ================================================================================
# Index 4 vs idx 21
# Similarity is 0.0725
# ================================================================================
# Index 4 vs idx 22
# Similarity is 0.08955223880597014
# ================================================================================
# Index 4 vs idx 23
# Similarity is 0.08169014084507042
# ================================================================================
# Index 4 vs idx 24
# Similarity is 0.05847953216374269
# ================================================================================
# Index 4 vs idx 25
# Similarity is 0.058394160583941604
# ================================================================================
# Index 4 vs idx 26
# Similarity is 0.04941860465116279
# ================================================================================
# Index 4 vs idx 27
# Similarity is 0.03305785123966942
# ================================================================================
# Index 4 vs idx 28
# Similarity is 0.04941860465116279
# ================================================================================
# Index 4 vs idx 29
# Similarity is 0.057279236276849645
# ================================================================================
# Index 4 vs idx 30
# Similarity is 0.03536345776031434
# ================================================================================
# Index 4 vs idx 31
# Similarity is 0.0893371757925072
# ================================================================================
# Index 4 vs idx 32
# Similarity is 0.07076923076923076
# ================================================================================
# Index 4 vs idx 33
# Similarity is 0.0963855421686747
# ================================================================================
# Index 4 vs idx 34
# Similarity is 0.0701219512195122
# ================================================================================
# Index 4 vs idx 35
# Similarity is 0.05543237250554324
# ================================================================================
# Index 4 vs idx 36
# Similarity is 0.07339449541284404
# ================================================================================
# Index 4 vs idx 37
# Similarity is 0.08333333333333333
# ================================================================================
# Index 4 vs idx 38
# Similarity is 0.07419354838709677
# ================================================================================
# Index 4 vs idx 39
# Similarity is 0.06406685236768803
# ================================================================================
# Index 4 vs idx 40
# Similarity is 0.06629834254143646
# ================================================================================
# Index 4 vs idx 41
# Similarity is 0.06172839506172839
# ================================================================================
# Index 4 vs idx 42
# Similarity is 0.052924791086350974
# ================================================================================
# Index 5 vs idx 6
# Similarity is 0.06902985074626866
# ================================================================================
# Index 5 vs idx 7
# Similarity is 0.06941838649155722
# ================================================================================
# Index 5 vs idx 8
# Similarity is 0.06386861313868614
# ================================================================================
# Index 5 vs idx 9
# Similarity is 0.052854122621564484
# ================================================================================
# Index 5 vs idx 10
# Similarity is 0.028481012658227847
# ================================================================================
# Index 5 vs idx 11
# Similarity is 0.03255813953488372
# ================================================================================
# Index 5 vs idx 12
# Similarity is 0.05417607223476298
# ================================================================================
# Index 5 vs idx 13
# Similarity is 0.05052631578947368
# ================================================================================
# Index 5 vs idx 14
# Similarity is 0.060291060291060294
# ================================================================================
# Index 5 vs idx 15
# Similarity is 0.07072368421052631
# ================================================================================
# Index 5 vs idx 16
# Similarity is 0.07157057654075547
# ================================================================================
# Index 5 vs idx 17
# Similarity is 0.06645569620253164
# ================================================================================
# Index 5 vs idx 18
# Similarity is 0.02824858757062147
# ================================================================================
# Index 5 vs idx 19
# Similarity is 0.06860706860706861
# ================================================================================
# Index 5 vs idx 20
# Similarity is 0.06652806652806653
# ================================================================================
# Index 5 vs idx 21
# Similarity is 0.05366726296958855
# ================================================================================
# Index 5 vs idx 22
# Similarity is 0.09443099273607748
# ================================================================================
# Index 5 vs idx 23
# Similarity is 0.06666666666666667
# ================================================================================
# Index 5 vs idx 24
# Similarity is 0.049253731343283584
# ================================================================================
# Index 5 vs idx 25
# Similarity is 0.03207810320781032
# ================================================================================
# Index 5 vs idx 26
# Similarity is 0.065439672801636
# ================================================================================
# Index 5 vs idx 27
# Similarity is 0.04430379746835443
# ================================================================================
# Index 5 vs idx 28
# Similarity is 0.065439672801636
# ================================================================================
# Index 5 vs idx 29
# Similarity is 0.045060658578856154
# ================================================================================
# Index 5 vs idx 30
# Similarity is 0.044072948328267476
# ================================================================================
# Index 5 vs idx 31
# Similarity is 0.09572301425661914
# ================================================================================
# Index 5 vs idx 32
# Similarity is 0.05394190871369295
# ================================================================================
# Index 5 vs idx 33
# Similarity is 0.056451612903225805
# ================================================================================
# Index 5 vs idx 34
# Similarity is 0.05360824742268041
# ================================================================================
# Index 5 vs idx 35
# Similarity is 0.037520391517128875
# ================================================================================
# Index 5 vs idx 36
# Similarity is 0.04318936877076412
# ================================================================================
# Index 5 vs idx 37
# Similarity is 0.043010752688172046
# ================================================================================
# Index 5 vs idx 38
# Similarity is 0.06479481641468683
# ================================================================================
# Index 5 vs idx 39
# Similarity is 0.09716599190283401
# ================================================================================
# Index 5 vs idx 40
# Similarity is 0.0963855421686747
# ================================================================================
# Index 5 vs idx 41
# Similarity is 0.061052631578947365
# ================================================================================
# Index 5 vs idx 42
# Similarity is 0.054901960784313725
# ================================================================================
# Index 6 vs idx 7
# Similarity is 0.979253112033195
# ================================================================================
# Index 6 vs idx 8
# Similarity is 0.07456140350877193
# ================================================================================
# Index 6 vs idx 9
# Similarity is 0.046511627906976744
# ================================================================================
# Index 6 vs idx 10
# Similarity is 0.08576998050682261
# ================================================================================
# Index 6 vs idx 11
# Similarity is 0.0872865275142315
# ================================================================================
# Index 6 vs idx 12
# Similarity is 0.16149068322981366
# ================================================================================
# Index 6 vs idx 13
# Similarity is 0.14689265536723164
# ================================================================================
# Index 6 vs idx 14
# Similarity is 0.07751937984496124
# ================================================================================
# Index 6 vs idx 15
# Similarity is 0.05084745762711865
# ================================================================================
# Index 6 vs idx 16
# Similarity is 0.12342569269521411
# ================================================================================
# Index 6 vs idx 17
# Similarity is 0.05253623188405797
# ================================================================================
# Index 6 vs idx 18
# Similarity is 0.06010016694490818
# ================================================================================
# Index 6 vs idx 19
# Similarity is 0.07948717948717948
# ================================================================================
# Index 6 vs idx 20
# Similarity is 0.05263157894736842
# ================================================================================
# Index 6 vs idx 21
# Similarity is 0.05084745762711865
# ================================================================================
# Index 6 vs idx 22
# Similarity is 0.08132530120481928
# ================================================================================
# Index 6 vs idx 23
# Similarity is 0.05620608899297424
# ================================================================================
# Index 6 vs idx 24
# Similarity is 0.04631217838765009
# ================================================================================
# Index 6 vs idx 25
# Similarity is 0.05203252032520325
# ================================================================================
# Index 6 vs idx 26
# Similarity is 0.049019607843137254
# ================================================================================
# Index 6 vs idx 27
# Similarity is 0.038461538461538464
# ================================================================================
# Index 6 vs idx 28
# Similarity is 0.049019607843137254
# ================================================================================
# Index 6 vs idx 29
# Similarity is 0.10629067245119306
# ================================================================================
# Index 6 vs idx 30
# Similarity is 0.03664921465968586
# ================================================================================
# Index 6 vs idx 31
# Similarity is 0.08536585365853659
# ================================================================================
# Index 6 vs idx 32
# Similarity is 0.058673469387755105
# ================================================================================
# Index 6 vs idx 33
# Similarity is 0.06947890818858561
# ================================================================================
# Index 6 vs idx 34
# Similarity is 0.05822784810126582
# ================================================================================
# Index 6 vs idx 35
# Similarity is 0.09919028340080972
# ================================================================================
# Index 6 vs idx 36
# Similarity is 0.10766045548654245
# ================================================================================
# Index 6 vs idx 37
# Similarity is 0.05945945945945946
# ================================================================================
# Index 6 vs idx 38
# Similarity is 0.07526881720430108
# ================================================================================
# Index 6 vs idx 39
# Similarity is 0.11970074812967581
# ================================================================================
# Index 6 vs idx 40
# Similarity is 0.11576354679802955
# ================================================================================
# Index 6 vs idx 41
# Similarity is 0.03007518796992481
# ================================================================================
# Index 6 vs idx 42
# Similarity is 0.03009259259259259
# ================================================================================
# Index 7 vs idx 8
# Similarity is 0.07505518763796909
# ================================================================================
# Index 7 vs idx 9
# Similarity is 0.046875
# ================================================================================
# Index 7 vs idx 10
# Similarity is 0.08627450980392157
# ================================================================================
# Index 7 vs idx 11
# Similarity is 0.08778625954198473
# ================================================================================
# Index 7 vs idx 12
# Similarity is 0.16300940438871472
# ================================================================================
# Index 7 vs idx 13
# Similarity is 0.14814814814814814
# ================================================================================
# Index 7 vs idx 14
# Similarity is 0.07532467532467532
# ================================================================================
# Index 7 vs idx 15
# Similarity is 0.05113636363636364
# ================================================================================
# Index 7 vs idx 16
# Similarity is 0.12436548223350254
# ================================================================================
# Index 7 vs idx 17
# Similarity is 0.05474452554744526
# ================================================================================
# Index 7 vs idx 18
# Similarity is 0.06040268456375839
# ================================================================================
# Index 7 vs idx 19
# Similarity is 0.08010335917312661
# ================================================================================
# Index 7 vs idx 20
# Similarity is 0.05569620253164557
# ================================================================================
# Index 7 vs idx 21
# Similarity is 0.04893617021276596
# ================================================================================
# Index 7 vs idx 22
# Similarity is 0.07878787878787878
# ================================================================================
# Index 7 vs idx 23
# Similarity is 0.05660377358490566
# ================================================================================
# Index 7 vs idx 24
# Similarity is 0.04655172413793104
# ================================================================================
# Index 7 vs idx 25
# Similarity is 0.054009819967266774
# ================================================================================
# Index 7 vs idx 26
# Similarity is 0.046798029556650245
# ================================================================================
# Index 7 vs idx 27
# Similarity is 0.04059040590405904
# ================================================================================
# Index 7 vs idx 28
# Similarity is 0.046798029556650245
# ================================================================================
# Index 7 vs idx 29
# Similarity is 0.10698689956331878
# ================================================================================
# Index 7 vs idx 30
# Similarity is 0.03684210526315789
# ================================================================================
# Index 7 vs idx 31
# Similarity is 0.085995085995086
# ================================================================================
# Index 7 vs idx 32
# Similarity is 0.05912596401028278
# ================================================================================
# Index 7 vs idx 33
# Similarity is 0.07
# ================================================================================
# Index 7 vs idx 34
# Similarity is 0.058673469387755105
# ================================================================================
# Index 7 vs idx 35
# Similarity is 0.10204081632653061
# ================================================================================
# Index 7 vs idx 36
# Similarity is 0.10833333333333334
# ================================================================================
# Index 7 vs idx 37
# Similarity is 0.05994550408719346
# ================================================================================
# Index 7 vs idx 38
# Similarity is 0.07297297297297298
# ================================================================================
# Index 7 vs idx 39
# Similarity is 0.11779448621553884
# ================================================================================
# Index 7 vs idx 40
# Similarity is 0.11662531017369727
# ================================================================================
# Index 7 vs idx 41
# Similarity is 0.03291139240506329
# ================================================================================
# Index 7 vs idx 42
# Similarity is 0.030303030303030304
# ================================================================================
# Index 8 vs idx 9
# Similarity is 0.07792207792207792
# ================================================================================
# Index 8 vs idx 10
# Similarity is 0.03656307129798903
# ================================================================================
# Index 8 vs idx 11
# Similarity is 0.0392156862745098
# ================================================================================
# Index 8 vs idx 12
# Similarity is 0.05785123966942149
# ================================================================================
# Index 8 vs idx 13
# Similarity is 0.053164556962025315
# ================================================================================
# Index 8 vs idx 14
# Similarity is 0.04656862745098039
# ================================================================================
# Index 8 vs idx 15
# Similarity is 0.07372400756143667
# ================================================================================
# Index 8 vs idx 16
# Similarity is 0.07801418439716312
# ================================================================================
# Index 8 vs idx 17
# Similarity is 0.08639705882352941
# ================================================================================
# Index 8 vs idx 18
# Similarity is 0.03864734299516908
# ================================================================================
# Index 8 vs idx 19
# Similarity is 0.06157635467980296
# ================================================================================
# Index 8 vs idx 20
# Similarity is 0.059113300492610835
# ================================================================================
# Index 8 vs idx 21
# Similarity is 0.045454545454545456
# ================================================================================
# Index 8 vs idx 22
# Similarity is 0.12158054711246201
# ================================================================================
# Index 8 vs idx 23
# Similarity is 0.06960556844547564
# ================================================================================
# Index 8 vs idx 24
# Similarity is 0.05263157894736842
# ================================================================================
# Index 8 vs idx 25
# Similarity is 0.03627760252365931
# ================================================================================
# Index 8 vs idx 26
# Similarity is 0.09226932668329177
# ================================================================================
# Index 8 vs idx 27
# Similarity is 0.04151624548736462
# ================================================================================
# Index 8 vs idx 28
# Similarity is 0.09226932668329177
# ================================================================================
# Index 8 vs idx 29
# Similarity is 0.06995884773662552
# ================================================================================
# Index 8 vs idx 30
# Similarity is 0.04317789291882556
# ================================================================================
# Index 8 vs idx 31
# Similarity is 0.1016949152542373
# ================================================================================
# Index 8 vs idx 32
# Similarity is 0.05459057071960298
# ================================================================================
# Index 8 vs idx 33
# Similarity is 0.06521739130434782
# ================================================================================
# Index 8 vs idx 34
# Similarity is 0.054187192118226604
# ================================================================================
# Index 8 vs idx 35
# Similarity is 0.06756756756756757
# ================================================================================
# Index 8 vs idx 36
# Similarity is 0.05009633911368015
# ================================================================================
# Index 8 vs idx 37
# Similarity is 0.05789473684210526
# ================================================================================
# Index 8 vs idx 38
# Similarity is 0.06217616580310881
# ================================================================================
# Index 8 vs idx 39
# Similarity is 0.09285714285714286
# ================================================================================
# Index 8 vs idx 40
# Similarity is 0.0971563981042654
# ================================================================================
# Index 8 vs idx 41
# Similarity is 0.10789473684210527
# ================================================================================
# Index 8 vs idx 42
# Similarity is 0.09112709832134293
# ================================================================================
# Index 9 vs idx 10
# Similarity is 0.05240174672489083
# ================================================================================
# Index 9 vs idx 11
# Similarity is 0.052854122621564484
# ================================================================================
# Index 9 vs idx 12
# Similarity is 0.05653710247349823
# ================================================================================
# Index 9 vs idx 13
# Similarity is 0.050793650793650794
# ================================================================================
# Index 9 vs idx 14
# Similarity is 0.08571428571428572
# ================================================================================
# Index 9 vs idx 15
# Similarity is 0.05689277899343545
# ================================================================================
# Index 9 vs idx 16
# Similarity is 0.07536231884057971
# ================================================================================
# Index 9 vs idx 17
# Similarity is 0.05636743215031315
# ================================================================================
# Index 9 vs idx 18
# Similarity is 0.02564102564102564
# ================================================================================
# Index 9 vs idx 19
# Similarity is 0.0778816199376947
# ================================================================================
# Index 9 vs idx 20
# Similarity is 0.09177215189873418
# ================================================================================
# Index 9 vs idx 21
# Similarity is 0.07124681933842239
# ================================================================================
# Index 9 vs idx 22
# Similarity is 0.09652509652509653
# ================================================================================
# Index 9 vs idx 23
# Similarity is 0.10263929618768329
# ================================================================================
# Index 9 vs idx 24
# Similarity is 0.07429718875502007
# ================================================================================
# Index 9 vs idx 25
# Similarity is 0.04
# ================================================================================
# Index 9 vs idx 26
# Similarity is 0.06006006006006006
# ================================================================================
# Index 9 vs idx 27
# Similarity is 0.0603448275862069
# ================================================================================
# Index 9 vs idx 28
# Similarity is 0.06006006006006006
# ================================================================================
# Index 9 vs idx 29
# Similarity is 0.0875
# ...
# Index 27 vs idx 28
# Similarity is 0.025896414342629483
# ================================================================================
# Index 27 vs idx 29
# Similarity is 0.054770318021201414
# ================================================================================
# Index 27 vs idx 30
# Similarity is 0.5691244239631337
# ================================================================================
# Index 27 vs idx 31
# Similarity is 0.05555555555555555
# ================================================================================
# Index 27 vs idx 32
# Similarity is 0.06581740976645435
# ================================================================================
# Index 27 vs idx 33
# Similarity is 0.04435483870967742
# ================================================================================
# Index 27 vs idx 34
# Similarity is 0.06540084388185655
# ================================================================================
# Index 27 vs idx 35
# Similarity is 0.05
# ================================================================================
# Index 27 vs idx 36
# Similarity is 0.048903878583473864
# ================================================================================
# Index 27 vs idx 37
# Similarity is 0.05506607929515418
# ================================================================================
# Index 27 vs idx 38
# Similarity is 0.04956896551724138
# ================================================================================
# Index 27 vs idx 39
# Similarity is 0.04483430799220273
# ================================================================================
# Index 27 vs idx 40
# Similarity is 0.046511627906976744
# ================================================================================
# Index 27 vs idx 41
# Similarity is 0.046218487394957986
# ================================================================================
# Index 27 vs idx 42
# Similarity is 0.05765407554671968
# ================================================================================
# Index 28 vs idx 29
# Similarity is 0.052873563218390804
# ================================================================================
# Index 28 vs idx 30
# Similarity is 0.028462998102466792
# ================================================================================
# Index 28 vs idx 31
# Similarity is 0.11331444759206799
# ================================================================================
# Index 28 vs idx 32
# Similarity is 0.04610951008645533
# ================================================================================
# Index 28 vs idx 33
# Similarity is 0.0440771349862259
# ================================================================================
# Index 28 vs idx 34
# Similarity is 0.045714285714285714
# ================================================================================
# Index 28 vs idx 35
# Similarity is 0.046908315565031986
# ================================================================================
# Index 28 vs idx 36
# Similarity is 0.025477707006369428
# ================================================================================
# Index 28 vs idx 37
# Similarity is 0.046153846153846156
# ================================================================================
# Index 28 vs idx 38
# Similarity is 0.057750759878419454
# ================================================================================
# Index 28 vs idx 39
# Similarity is 0.08174386920980926
# ================================================================================
# Index 28 vs idx 40
# Similarity is 0.08086253369272237
# ================================================================================
# Index 28 vs idx 41
# Similarity is 0.0621301775147929
# ================================================================================
# Index 28 vs idx 42
# Similarity is 0.056451612903225805
# ================================================================================
# Index 29 vs idx 30
# Similarity is 0.04873949579831933
# ================================================================================
# Index 29 vs idx 31
# Similarity is 0.08447488584474885
# ================================================================================
# Index 29 vs idx 32
# Similarity is 0.0774818401937046
# ================================================================================
# Index 29 vs idx 33
# Similarity is 0.08470588235294117
# ================================================================================
# Index 29 vs idx 34
# Similarity is 0.07692307692307693
# ================================================================================
# Index 29 vs idx 35
# Similarity is 0.8365384615384616
# ================================================================================
# Index 29 vs idx 36
# Similarity is 0.13
# ================================================================================
# Index 29 vs idx 37
# Similarity is 0.08762886597938144
# ================================================================================
# Index 29 vs idx 38
# Similarity is 0.06435643564356436
# ================================================================================
# Index 29 vs idx 39
# Similarity is 0.06444444444444444
# ================================================================================
# Index 29 vs idx 40
# Similarity is 0.06387665198237885
# ================================================================================
# Index 29 vs idx 41
# Similarity is 0.06009615384615385
# ================================================================================
# Index 29 vs idx 42
# Similarity is 0.04856512141280353
# ================================================================================
# Index 30 vs idx 31
# Similarity is 0.04878048780487805
# ================================================================================
# Index 30 vs idx 32
# Similarity is 0.053784860557768925
# ================================================================================
# Index 30 vs idx 33
# Similarity is 0.04007633587786259
# ================================================================================
# Index 30 vs idx 34
# Similarity is 0.053465346534653464
# ================================================================================
# Index 30 vs idx 35
# Similarity is 0.052884615384615384
# ================================================================================
# Index 30 vs idx 36
# Similarity is 0.03179650238473768
# ================================================================================
# Index 30 vs idx 37
# Similarity is 0.04979253112033195
# ================================================================================
# Index 30 vs idx 38
# Similarity is 0.05112474437627812
# ================================================================================
# Index 30 vs idx 39
# Similarity is 0.048417132216014895
# ================================================================================
# Index 30 vs idx 40
# Similarity is 0.04805914972273567
# ================================================================================
# Index 30 vs idx 41
# Similarity is 0.06490872210953347
# ================================================================================
# Index 30 vs idx 42
# Similarity is 0.04291044776119403
# ================================================================================
# Index 31 vs idx 32
# Similarity is 0.07344632768361582
# ================================================================================
# Index 31 vs idx 33
# Similarity is 0.09090909090909091
# ================================================================================
# Index 31 vs idx 34
# Similarity is 0.07282913165266107
# ================================================================================
# Index 31 vs idx 35
# Similarity is 0.07627118644067797
# ================================================================================
# Index 31 vs idx 36
# Similarity is 0.07526881720430108
# ================================================================================
# Index 31 vs idx 37
# Similarity is 0.0851063829787234
# ================================================================================
# Index 31 vs idx 38
# Similarity is 0.08630952380952381
# ================================================================================
# Index 31 vs idx 39
# Similarity is 0.11891891891891893
# ================================================================================
# Index 31 vs idx 40
# Similarity is 0.11466666666666667
# ================================================================================
# Index 31 vs idx 41
# Similarity is 0.10588235294117647
# ================================================================================
# Index 31 vs idx 42
# Similarity is 0.10512129380053908
# ================================================================================
# Index 32 vs idx 33
# Similarity is 0.13664596273291926
# ================================================================================
# Index 32 vs idx 34
# Similarity is 0.9289617486338798
# ================================================================================
# Index 32 vs idx 35
# Similarity is 0.07174887892376682
# ================================================================================
# Index 32 vs idx 36
# Similarity is 0.10328638497652583
# ================================================================================
# Index 32 vs idx 37
# Similarity is 0.13937282229965156
# ================================================================================
# Index 32 vs idx 38
# Similarity is 0.07371794871794872
# ================================================================================
# Index 32 vs idx 39
# Similarity is 0.07865168539325842
# ================================================================================
# Index 32 vs idx 40
# Similarity is 0.07777777777777778
# ================================================================================
# Index 32 vs idx 41
# Similarity is 0.0880503144654088
# ================================================================================
# Index 32 vs idx 42
# Similarity is 0.08882521489971347
# ================================================================================
# Index 33 vs idx 34
# Similarity is 0.13538461538461538
# ================================================================================
# Index 33 vs idx 35
# Similarity is 0.07860262008733625
# ================================================================================
# Index 33 vs idx 36
# Similarity is 0.11981566820276497
# ================================================================================
# Index 33 vs idx 37
# Similarity is 0.16666666666666666
# ================================================================================
# Index 33 vs idx 38
# Similarity is 0.10031347962382445
# ================================================================================
# Index 33 vs idx 39
# Similarity is 0.07238605898123325
# ================================================================================
# Index 33 vs idx 40
# Similarity is 0.06878306878306878
# ================================================================================
# Index 33 vs idx 41
# Similarity is 0.07418397626112759
# ================================================================================
# Index 33 vs idx 42
# Similarity is 0.06166219839142091
# ================================================================================
# Index 34 vs idx 35
# Similarity is 0.07126948775055679
# ================================================================================
# Index 34 vs idx 36
# Similarity is 0.10256410256410256
# ================================================================================
# Index 34 vs idx 37
# Similarity is 0.13793103448275862
# ================================================================================
# Index 34 vs idx 38
# Similarity is 0.07301587301587302
# ================================================================================
# Index 34 vs idx 39
# Similarity is 0.07799442896935933
# ================================================================================
# Index 34 vs idx 40
# Similarity is 0.07713498622589532
# ================================================================================
# Index 34 vs idx 41
# Similarity is 0.08722741433021806
# ================================================================================
# Index 34 vs idx 42
# Similarity is 0.08806818181818182
# ================================================================================
# Index 35 vs idx 36
# Similarity is 0.12617702448210924
# ================================================================================
# Index 35 vs idx 37
# Similarity is 0.07819905213270142
# ================================================================================
# Index 35 vs idx 38
# Similarity is 0.05707762557077625
# ================================================================================
# Index 35 vs idx 39
# Similarity is 0.060041407867494824
# ================================================================================
# Index 35 vs idx 40
# Similarity is 0.06391752577319587
# ================================================================================
# Index 35 vs idx 41
# Similarity is 0.0651685393258427
# ================================================================================
# Index 35 vs idx 42
# Similarity is 0.04742268041237113
# ================================================================================
# Index 36 vs idx 37
# Similarity is 0.10918114143920596
# ================================================================================
# Index 36 vs idx 38
# Similarity is 0.06557377049180328
# ================================================================================
# Index 36 vs idx 39
# Similarity is 0.06553911205073996
# ================================================================================
# Index 36 vs idx 40
# Similarity is 0.0649895178197065
# ================================================================================
# Index 36 vs idx 41
# Similarity is 0.0639269406392694
# ================================================================================
# Index 36 vs idx 42
# Similarity is 0.07526881720430108
# ================================================================================
# Index 37 vs idx 38
# Similarity is 0.11428571428571428
# ================================================================================
# Index 37 vs idx 39
# Similarity is 0.08734939759036145
# ================================================================================
# Index 37 vs idx 40
# Similarity is 0.07988165680473373
# ================================================================================
# Index 37 vs idx 41
# Similarity is 0.066006600660066
# ================================================================================
# Index 37 vs idx 42
# Similarity is 0.06567164179104477
# ================================================================================
# Index 38 vs idx 39
# Similarity is 0.08211143695014662
# ================================================================================
# Index 38 vs idx 40
# Similarity is 0.07803468208092486
# ================================================================================
# Index 38 vs idx 41
# Similarity is 0.06774193548387097
# ================================================================================
# Index 38 vs idx 42
# Similarity is 0.061046511627906974
# ================================================================================
# Index 39 vs idx 40
# Similarity is 0.9009009009009009
# ================================================================================
# Index 39 vs idx 41
# Similarity is 0.07042253521126761
# ================================================================================
# Index 39 vs idx 42
# Similarity is 0.06426735218508997
# ================================================================================
# Index 40 vs idx 41
# Similarity is 0.07563025210084033
# ================================================================================
# Index 40 vs idx 42
# Similarity is 0.06361323155216285
# ================================================================================
# Index 41 vs idx 42
# Similarity is 0.5864978902953587
